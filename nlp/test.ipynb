# %%
import torch
BATCH, class_num = 128, 4
pred = torch.randn(BATCH, class_num)

# %%
predictions = zip(range(0, BATCH), pred.max(1)[1])

# %%
for i, pred in predictions:
    print("i: {}, label: {}".format(i, pred))
# Out:
# i: 0, label: 1
# i: 1, label: 2
# i: 2, label: 2
# i: 3, label: 0
# i: 4, label: 1
# i: 5, label: 0
# i: 6, label: 3
# i: 7, label: 3
# i: 8, label: 0
# i: 9, label: 3
# i: 10, label: 2
# i: 11, label: 0
# i: 12, label: 3
# i: 13, label: 3
# i: 14, label: 0
# i: 15, label: 3
# i: 16, label: 0
# i: 17, label: 0
# i: 18, label: 0
# i: 19, label: 2
# i: 20, label: 1
# i: 21, label: 2
# i: 22, label: 3
# i: 23, label: 3
# i: 24, label: 2
# i: 25, label: 1
# i: 26, label: 1
# i: 27, label: 1
# i: 28, label: 2
# i: 29, label: 3
# i: 30, label: 3
# i: 31, label: 1
# i: 32, label: 1
# i: 33, label: 2
# i: 34, label: 3
# i: 35, label: 0
# i: 36, label: 3
# i: 37, label: 0
# i: 38, label: 2
# i: 39, label: 3
# i: 40, label: 1
# i: 41, label: 0
# i: 42, label: 2
# i: 43, label: 1
# i: 44, label: 0
# i: 45, label: 1
# i: 46, label: 0
# i: 47, label: 0
# i: 48, label: 1
# i: 49, label: 1
# i: 50, label: 0
# i: 51, label: 3
# i: 52, label: 0
# i: 53, label: 2
# i: 54, label: 1
# i: 55, label: 1
# ...
